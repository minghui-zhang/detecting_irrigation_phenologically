# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('trainingpts_cleaned.csv', index_col = 0)

data.head()
# Out:
#    mod_B0_0  mod_B0_1  mod_B0_2  mod_B0_3  mod_B0_4  mod_B0_5  mod_B0_6  \
# 0  0.200212  0.214260  0.095794  0.237088  0.246048  0.336598  0.310465
# 1  0.444825  0.378180  0.418023  0.367307  0.417435  0.362797  0.405056
# 2  0.391427  0.342404  0.330443  0.335222  0.358131  0.323579  0.279447
# 3  0.221930  0.175103  0.170139  0.203599  0.170929  0.260337  0.205148
# 4  0.400937  0.367652  0.279104  0.299323  0.280226  0.304503  0.175922
#
#    mod_B0_7  mod_B0_8  mod_B0_9          ...            EVI_at_min2_missing  \
# 0  0.270645  0.188515  0.204236          ...                          False
# 1  0.367728  0.337898  0.318900          ...                          False
# 2  0.416388  0.401079  0.314834          ...                           True
# 3  0.260194  0.245417  0.328592          ...                          False
# 4  0.198228  0.220535  0.371426          ...                          False
#
#    EVI_at_infl2_missing  quarterPeriod_first_missing  EVI_at_peak2_missing  \
# 0                 False                        False                 False
# 1                 False                        False                 False
# 2                  True                        False                  True
# 3                 False                        False                 False
# 4                 False                        False                 False
#
#    fittedAmplitude_second_missing  quarterPeriod_second_missing  \
# 0                           False                         False
# 1                           False                         False
# 2                            True                         False
# 3                           False                         False
# 4                           False                         False
#
#    peakDiff_missing  peakDay_first_missing  EVI_at_infl1_missing  \
# 0             False                  False                 False
# 1             False                  False                 False
# 2              True                  False                 False
# 3             False                  False                 False
# 4             False                  False                 False
#
#    maxEVI_second_missing
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 130 columns]

# %%
# separate the predictor names into categories (for feature selection later)

mod_ts_cols = [colname for colname in data if colname.startswith('mod')]
non_ts_cols = list(set(data.columns) - set(mod_ts_cols))
phenospectral_cols = ['EVI_at_infl2', 'quarterPeriod_first','EVI_at_min1','quarterPeriod_second','fittedAmplitude_second',
                     'EVI_at_infl1','peakDay_first','EVI_at_peak2','peakDiff', 'maxEVI_first','EVI_at_min2',
                     'peakDay_second', 'maxEVI_second', 'EVI_at_peak1', 'fittedAmplitude_first',]
missingness_cols = [colname for colname in data if colname.endswith('missing')]
geographic_cols = ['lat', 'lon', 'state', 'region']
numerical_cols = mod_ts_cols + phenospectral_cols + missingness_cols
categorical_cols = ['region', 'state']
all_predictors = list(data.columns)
all_predictors.remove('class')

# %%
# include all information (timeseries, phenological and geographic) as predictors
X = data[all_predictors]
y = data['class']

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

print(y_test.head())
# Out:
# 7927    1
# 1740    0
# 359     0
# 7196    1
# 38      0
# Name: class, dtype: int64

# %%
# MODEL 1: mean imputation, then random forest with no parameter tuning, and using all predictors

# data frame to store model predictions
model1_pred_results = pd.DataFrame(columns=['model', 'tuning', 'geo_preds', 'region', 'threshold', 'auc', 'fp', 'fn', 'tp', 
                                     'tn', 'acc', 'num_training_pts', 'percent_irr_training'])
thresholds = np.arange(0.0, 1.1, 0.1)

# set predictors
numerical_cols_all = numerical_cols
categorical_cols_all = categorical_cols

# preprocessing pipelines for both numeric and categorical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean'))])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor_all = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_all),
        ('cat', categorical_transformer, categorical_cols_all)])

# Append classifier to preprocessing pipeline
pipeline_allpred_notuning = Pipeline(steps=[('preprocessor', preprocessor_all),
                      ('rf', RandomForestClassifier())])

# training
pipeline_allpred_notuning.fit(X_train, y_train)

total_train_points = len(y_train)
percent_irr_training = np.mean(y_train)

# prediction with different thresholds
y_pred_prob = pipeline_allpred_notuning.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_test, y_pred_prob)

for threshold in thresholds:
    y_pred = np.multiply(np.array(y_pred_prob > threshold), 1)

    conf_mat = confusion_matrix(y_test, y_pred)

    FP = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
    FN = conf_mat[1,0]/(conf_mat[1,0] + conf_mat[1,1])
    TP = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
    TN = conf_mat[0,0]/(conf_mat[0,0] + conf_mat[0,1])
    
    acc = (TP + TN)/(FP + FN + TP + TN)
    
    model1_pred_results = model1_pred_results.append({'model': 'rf', 'tuning': False, 'geo_preds': True, 'region': 'Brazil',
                                       'threshold': threshold, 'auc': auc, 'fp': FP, 'fn': FN, 'tp': TP, 'tn': TN, 'acc': acc,
                                       'num_training_pts': total_train_points, 
                                       'percent_irr_training': percent_irr_training}, ignore_index=True)

# print performance metrics
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC Curve')
plt.show()

print(model1_pred_results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#    model tuning geo_preds  region  threshold       auc        fp        fn  \
# 0     rf  False      True  Brazil        0.0  0.912898  0.820796  0.004635
# 1     rf  False      True  Brazil        0.1  0.912898  0.612279  0.019699
# 2     rf  False      True  Brazil        0.2  0.912898  0.443031  0.033024
# 3     rf  False      True  Brazil        0.3  0.912898  0.301991  0.059676
# 4     rf  False      True  Brazil        0.4  0.912898  0.206305  0.113557
# 5     rf  False      True  Brazil        0.5  0.912898  0.136615  0.183082
# 6     rf  False      True  Brazil        0.6  0.912898  0.085177  0.271727
# 7     rf  False      True  Brazil        0.7  0.912898  0.045354  0.418888
# 8     rf  False      True  Brazil        0.8  0.912898  0.023230  0.599073
# 9     rf  False      True  Brazil        0.9  0.912898  0.006637  0.820394
# 10    rf  False      True  Brazil        1.0  0.912898  0.000000  1.000000
#
#           tp        tn       acc num_training_pts  percent_irr_training
# 0   0.995365  0.179204  0.587284             8243              0.513163
# 1   0.980301  0.387721  0.684011             8243              0.513163
# 2   0.966976  0.556969  0.761972             8243              0.513163
# 3   0.940324  0.698009  0.819167             8243              0.513163
# 4   0.886443  0.793695  0.840069             8243              0.513163
# 5   0.816918  0.863385  0.840151             8243              0.513163
# 6   0.728273  0.914823  0.821548             8243              0.513163
# 7   0.581112  0.954646  0.767879             8243              0.513163
# 8   0.400927  0.976770  0.688848             8243              0.513163
# 9   0.179606  0.993363  0.586484             8243              0.513163
# 10  0.000000  1.000000  0.500000             8243              0.513163

# %%
# MODEL 2: mean imputation, random forest with no parameter tuning, using all predictors EXCEPT geographic

# data frame to store model predictions
model2_pred_results = pd.DataFrame(columns=['model', 'tuning', 'geo_preds', 'region', 'threshold', 'auc', 'fp', 'fn', 'tp', 
                                     'tn', 'acc', 'num_training_pts', 'percent_irr_training'])
thresholds = np.arange(0.0, 1.1, 0.1)

# set predictors
numerical_cols_nongeo = list(set(numerical_cols) - set(geographic_cols))
categorical_cols_nongeo = list(set(categorical_cols) - set(geographic_cols))

# preprocessing pipelines for both numeric and categorical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean'))])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor_nongeo = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_nongeo),
        ('cat', categorical_transformer, categorical_cols_nongeo)])

# Append classifier to preprocessing pipeline
pipeline_nongeo_notuning = Pipeline(steps=[('preprocessor', preprocessor_nongeo),
                      ('rf', RandomForestClassifier())])

# training
pipeline_nongeo_notuning.fit(X_train, y_train)

total_train_points = len(y_train)
percent_irr_training = np.mean(y_train)

# prediction with different thresholds
#acc_nongeo_notuning = pipeline_nongeo_notuning.score(X_test, y_test)
y_pred_prob = pipeline_nongeo_notuning.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_test, y_pred_prob)

for threshold in thresholds:
    y_pred = np.multiply(np.array(y_pred_prob > threshold), 1)

    conf_mat = confusion_matrix(y_test, y_pred)

    FP = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
    FN = conf_mat[1,0]/(conf_mat[1,0] + conf_mat[1,1])
    TP = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
    TN = conf_mat[0,0]/(conf_mat[0,0] + conf_mat[0,1])
    
    acc = (TP + TN)/(FP + FN + TP + TN)
    
    model2_pred_results = model2_pred_results.append({'model': 'rf', 'tuning': False, 'geo_preds': False, 'region': 'Brazil',
                                       'threshold': threshold, 'auc': auc, 'fp': FP, 'fn': FN, 'tp': TP, 'tn': TN, 'acc': acc,
                                       'num_training_pts': total_train_points, 
                                       'percent_irr_training': percent_irr_training}, ignore_index=True)

# print performance metrics
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC Curve')
plt.show()

print(model2_pred_results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#    model tuning geo_preds  region  threshold      auc        fp        fn  \
# 0     rf   True     False  Brazil        0.0  0.83699  0.939159  0.002897
# 1     rf   True     False  Brazil        0.1  0.83699  0.797013  0.009849
# 2     rf   True     False  Brazil        0.2  0.83699  0.637168  0.042294
# 3     rf   True     False  Brazil        0.3  0.83699  0.475664  0.084009
# 4     rf   True     False  Brazil        0.4  0.83699  0.326881  0.157590
# 5     rf   True     False  Brazil        0.5  0.83699  0.208518  0.289108
# 6     rf   True     False  Brazil        0.6  0.83699  0.111173  0.433372
# 7     rf   True     False  Brazil        0.7  0.83699  0.045354  0.605446
# 8     rf   True     False  Brazil        0.8  0.83699  0.013274  0.780997
# 9     rf   True     False  Brazil        0.9  0.83699  0.003319  0.919467
# 10    rf   True     False  Brazil        1.0  0.83699  0.000000  1.000000
#
#           tp        tn       acc num_training_pts  percent_irr_training
# 0   0.997103  0.060841  0.528972             8243              0.513163
# 1   0.990151  0.202987  0.596569             8243              0.513163
# 2   0.957706  0.362832  0.660269             8243              0.513163
# 3   0.915991  0.524336  0.720164             8243              0.513163
# 4   0.842410  0.673119  0.757765             8243              0.513163
# 5   0.710892  0.791482  0.751187             8243              0.513163
# 6   0.566628  0.888827  0.727728             8243              0.513163
# 7   0.394554  0.954646  0.674600             8243              0.513163
# 8   0.219003  0.986726  0.602865             8243              0.513163
# 9   0.080533  0.996681  0.538607             8243              0.513163
# 10  0.000000  1.000000  0.500000             8243              0.513163

# %% [markdown]
# When we get rid of geographic features, our prediction accuracy lowers from 0.84 to 0.76. This decline may be worth the extra predictive power if irrigation expands geographically.

# %%
# MODEL 3: random forest with tuning, using all predictors EXCEPT geographic

# set predictors
numerical_cols_nongeo = list(set(numerical_cols) - set(geographic_cols))
categorical_cols_nongeo = list(set(categorical_cols) - set(geographic_cols))

# set tuning space

n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)] # Number of trees in random forest
max_features = ['auto', 'sqrt'] # Number of features to consider at every split
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)] # Maximum number of levels in tree
max_depth.append(None)
min_samples_split = [2, 5, 10] # Minimum number of samples required to split a node
min_samples_leaf = [1, 2, 4] # Minimum number of samples required at each leaf node
bootstrap = [True, False] # Method of selecting samples for training each tree

# Create the random grid
random_grid = {'preprocessor__num__imputer__strategy': ['mean', 'median'],
                'rf__n_estimators': n_estimators,
               'rf__max_features': max_features,
               'rf__max_depth': max_depth,
               'rf__min_samples_split': min_samples_split,
               'rf__min_samples_leaf': min_samples_leaf,
               'rf__bootstrap': bootstrap}

# preprocessing pipelines for both numeric and categorical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor_nongeo = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_nongeo),
        ('cat', categorical_transformer, categorical_cols_nongeo)])

# Append classifier to preprocessing pipeline
pipeline_nongeo = Pipeline(steps=[('preprocessor', preprocessor_nongeo),
                      ('rf', RandomForestClassifier())])

rf_nongeo_tuned = RandomizedSearchCV(estimator = pipeline_nongeo, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_nongeo_tuned.fit(X_train, y_train)

print(rf_nongeo_tuned.best_params_)

total_train_points = len(y_train)
percent_irr_training = np.mean(y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 30.4min finished
# {'rf__n_estimators': 1400, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__max_features': 'auto', 'rf__max_depth': 90, 'rf__bootstrap': False, 'preprocessor__num__imputer__strategy': 'mean'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-1ba87c5e74a1> in <module>
#      84 plt.show()
#      85
# ---> 86 print(model2_pred_results)
#
# NameError: name 'model2_pred_results' is not defined

# %%
# data frame to store model predictions
model3_pred_results = pd.DataFrame(columns=['model', 'tuning', 'geo_preds', 'region', 'threshold', 'auc', 'fp', 'fn', 'tp', 
                                     'tn', 'acc', 'num_training_pts', 'percent_irr_training'])
thresholds = np.arange(0.0, 1.1, 0.1)

# prediction with different thresholds
y_pred_prob = rf_nongeo_tuned.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_test, y_pred_prob)

for threshold in thresholds:
    y_pred = np.multiply(np.array(y_pred_prob > threshold), 1)

    conf_mat = confusion_matrix(y_test, y_pred)

    FP = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
    FN = conf_mat[1,0]/(conf_mat[1,0] + conf_mat[1,1])
    TP = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
    TN = conf_mat[0,0]/(conf_mat[0,0] + conf_mat[0,1])
    
    acc = (TP + TN)/(FP + FN + TP + TN)
    
    model3_pred_results = model3_pred_results.append({'model': 'rf', 'tuning': True, 'geo_preds': False, 'region': 'Brazil',
                                       'threshold': threshold, 'auc': auc, 'fp': FP, 'fn': FN, 'tp': TP, 'tn': TN, 'acc': acc,
                                       'num_training_pts': total_train_points, 
                                       'percent_irr_training': percent_irr_training}, ignore_index=True)

# print performance metrics
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC Curve')
plt.show()

print(model3_pred_results)
# Out:
#    model tuning geo_preds  region  threshold       auc        fp        fn  \
# 0     rf   True     False  Brazil        0.0  0.908702  1.000000  0.000000
# 1     rf   True     False  Brazil        0.1  0.908702  0.925332  0.000000
# 2     rf   True     False  Brazil        0.2  0.908702  0.745575  0.005794
# 3     rf   True     False  Brazil        0.3  0.908702  0.552544  0.023175
# 4     rf   True     False  Brazil        0.4  0.908702  0.356748  0.072422
# 5     rf   True     False  Brazil        0.5  0.908702  0.187500  0.158169
# 6     rf   True     False  Brazil        0.6  0.908702  0.080199  0.304751
# 7     rf   True     False  Brazil        0.7  0.908702  0.026549  0.489571
# 8     rf   True     False  Brazil        0.8  0.908702  0.007190  0.698146
# 9     rf   True     False  Brazil        0.9  0.908702  0.001106  0.885863
# 10    rf   True     False  Brazil        1.0  0.908702  0.000000  1.000000
#
#           tp        tn       acc num_training_pts  percent_irr_training
# 0   1.000000  0.000000  0.500000             8243              0.513163
# 1   1.000000  0.074668  0.537334             8243              0.513163
# 2   0.994206  0.254425  0.624316             8243              0.513163
# 3   0.976825  0.447456  0.712140             8243              0.513163
# 4   0.927578  0.643252  0.785415             8243              0.513163
# 5   0.841831  0.812500  0.827165             8243              0.513163
# 6   0.695249  0.919801  0.807525             8243              0.513163
# 7   0.510429  0.973451  0.741940             8243              0.513163
# 8   0.301854  0.992810  0.647332             8243              0.513163
# 9   0.114137  0.998894  0.556515             8243              0.513163
# 10  0.000000  1.000000  0.500000             8243              0.513163

# %% [markdown]
# results of parameter tuning: {'rf__n_estimators': 1400, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__max_features': 'auto', 'rf__max_depth': 90, 'rf__bootstrap': False, 'preprocessor__num__imputer__strategy': 'mean'}

# %% [markdown]
# We will choose a threshold that gives a true positive rate of at least 0.85 at the expense of a lower true negative rate, allowing a conservative estimate of irrigation water requirements. The chosen threshold for a model fit over all Brazil is 0.4.

# %% [markdown]
# Following cross validation with grid search, we find that accuracy increases to 0.83 from 0.76 without geographic features. This performance is on par with the accuracy seen with the untuned model that uses geographic features.

# %%
# not all years have the same set modis columns, so before training the final model, 
# extract only the columns that are present in all years

mod_ts_cols_allyears = set(mod_ts_cols)

years_list = list(range(2004, 2014)) + list(range(2015, 2019))
for year in years_list:
    data_year = pd.read_csv('predictionpts_cleaned_' + str(year) + '.csv', index_col = 0)
    mod_ts_cols_year = [colname for colname in data_year if colname.startswith('mod')]
    mod_ts_cols_allyears = mod_ts_cols_allyears.intersection(set(mod_ts_cols_year))

print(mod_ts_cols_allyears)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# {'mod_B0_32', 'mod_B0_47', 'mod_B0_55', 'mod_B0_11', 'mod_B0_20', 'mod_B0_35', 'mod_B0_36', 'mod_B0_40', 'mod_B0_88', 'mod_B0_33', 'mod_B0_19', 'mod_B0_45', 'mod_B0_73', 'mod_B0_29', 'mod_B0_3', 'mod_B0_58', 'mod_B0_90', 'mod_B0_26', 'mod_B0_0', 'mod_B0_25', 'mod_B0_78', 'mod_B0_53', 'mod_B0_59', 'mod_B0_44', 'mod_B0_80', 'mod_B0_61', 'mod_B0_43', 'mod_B0_71', 'mod_B0_16', 'mod_B0_60', 'mod_B0_82', 'mod_B0_70', 'mod_B0_64', 'mod_B0_76', 'mod_B0_37', 'mod_B0_15', 'mod_B0_14', 'mod_B0_66', 'mod_B0_8', 'mod_B0_22', 'mod_B0_57', 'mod_B0_67', 'mod_B0_9', 'mod_B0_63', 'mod_B0_81', 'mod_B0_10', 'mod_B0_79', 'mod_B0_27', 'mod_B0_54', 'mod_B0_28', 'mod_B0_91', 'mod_B0_84', 'mod_B0_17', 'mod_B0_65', 'mod_B0_34', 'mod_B0_56', 'mod_B0_38', 'mod_B0_24', 'mod_B0_18', 'mod_B0_77', 'mod_B0_72', 'mod_B0_31', 'mod_B0_30', 'mod_B0_21', 'mod_B0_12', 'mod_B0_13', 'mod_B0_62', 'mod_B0_75', 'mod_B0_68', 'mod_B0_69', 'mod_B0_23', 'mod_B0_42', 'mod_B0_74', 'mod_B0_46', 'mod_B0_7'}

# %%
# train final model (no geographic predictors and with tuned parameters)
# use it to make predictions of irrigation growth in other years
# use only predictors that appear in all years

chosen_threshold = 0.4

# set predictors
numerical_cols_allyears = list(mod_ts_cols_allyears) + phenospectral_cols + missingness_cols
numerical_cols_nongeo = list(set(numerical_cols_allyears) - set(geographic_cols))
categorical_cols_nongeo = list(set(categorical_cols) - set(geographic_cols))

# preprocessing pipelines for both numeric and categorical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean'))])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor_nongeo = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_nongeo),
        ('cat', categorical_transformer, categorical_cols_nongeo)])

# Append classifier to preprocessing pipeline
tuned_rf = RandomForestClassifier(n_estimators = 1400, min_samples_split = 5, 
                                   min_samples_leaf = 1, max_features = 'auto', max_depth = 90, 
                                   bootstrap = False)

pipeline_final = Pipeline(steps=[('preprocessor', preprocessor_nongeo),
                      ('rf', tuned_rf)])

# training
pipeline_final.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('num', Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose...obs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
# predictions in new years

# data frame to save predicted percent irrigation in each region
columns_list = ['year', 'Brazil', 'SUL', 'CENTRO-OESTE', 'SUDESTE', 'NORDESTE', 'NORTE']
predicted_irrig = pd.DataFrame(columns = columns_list)

years_list = list(range(2004, 2014)) + list(range(2015, 2019))

for year in years_list:
    data_year = pd.read_csv('predictionpts_cleaned_' + str(year) + '.csv', index_col = 0)
    chosen_predictors = numerical_cols_nongeo + categorical_cols_nongeo
    X_year = data_year[chosen_predictors]

    #prediction = pipeline_final.predict(X_year)
    y_pred_prob = pipeline_final.predict_proba(X_year)[:,1]
    prediction = np.multiply(np.array(y_pred_prob > chosen_threshold), 1)
    
    data_year['prediction'] = prediction
    
    # percent irrigated by region
    percent_Brazil = prediction.mean()
    percent_south = data_year[data_year.region == 'SUL'].prediction.mean()
    percent_centerwest = data_year[data_year.region == 'CENTRO-OESTE'].prediction.mean()
    percent_southeast = data_year[data_year.region == 'SUDESTE'].prediction.mean()
    percent_northeast = data_year[data_year.region == 'NORDESTE'].prediction.mean()
    percent_north = data_year[data_year.region == 'NORTE'].prediction.mean()

    predicted_irrig.loc[len(predicted_irrig)] = [year, percent_Brazil, percent_south,
                                             percent_centerwest, percent_southeast,
                                             percent_northeast, percent_north]
    print(year)
    
print(predicted_irrig)
# Out:
# 2004
# 2005
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2006
# 2007
# 2008
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2009
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2010
# 2011
# 2012
# 2013
# 2015
# 2016
# 2017
# 2018
#       year    Brazil       SUL  CENTRO-OESTE   SUDESTE  NORDESTE     NORTE
# 0   2004.0  0.472020  0.426621      0.460604  0.616702  0.314607  0.202703
# 1   2005.0  0.498135  0.488388      0.470339  0.639477  0.316334  0.294118
# 2   2006.0  0.510276  0.491108      0.490828  0.610431  0.410572  0.353448
# 3   2007.0  0.528134  0.394198      0.544171  0.692229  0.434934  0.406780
# 4   2008.0  0.446763  0.404161      0.422274  0.565915  0.367657  0.316667
# 5   2009.0  0.511667  0.528469      0.445514  0.633760  0.410949  0.416000
# 6   2010.0  0.588215  0.398224      0.668910  0.745701  0.441441  0.434109
# 7   2011.0  0.525377  0.338792      0.512853  0.759308  0.459128  0.352941
# 8   2012.0  0.637267  0.555783      0.638945  0.776693  0.510738  0.582734
# 9   2013.0  0.618407  0.517583      0.625977  0.804925  0.432140  0.377622
# 10  2015.0  0.673359  0.509563      0.706703  0.875595  0.512920  0.412121
# 11  2016.0  0.595568  0.481418      0.626992  0.762900  0.412145  0.380952
# 12  2017.0  0.617275  0.388776      0.680358  0.816179  0.507802  0.354651
# 13  2018.0  0.596083  0.439348      0.626518  0.788177  0.440431  0.392857

# %%
# plot predictions

tidy_predictions = predicted_irrig.melt(id_vars = ['year'], value_name = 'percent_irrigated', 
                                        var_name = 'region')

sns.lineplot(x = 'year', y = 'percent_irrigated', data = tidy_predictions, hue = 'region')
plt.title('Percent irrigation, predicted; not using geogrpahic predictors')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Percent irrigation increased from 2004 to 2015 in all regions, then seemed to decline from 2015 to 2018 in most places. The spatial pattern in irrigation is also apparent: irrigation is very common in the south east and least common in the north. Both the north and southeast experience a large incerase in irrigated area in the 2000s, while irrigation stayed relatively constant in the south. There's bias in the percent irrigation that we predict: areas with high irrigation frequency in 2014 (southeast) are underestimated, and areas with low irrigated frequency in 2014 (north) are overestimated. However, we can still draw insights about the temporal trends within each region.

# %% [markdown]
# Although the use of geographic information may bias the model, it may still be useful to incorporate regional information. Because different regions have different precipitation seasonality, the modis acquisition dates that best separate the classes are different, and it may be useful to fit a separate classifier per region.

# %%
# choose a threshold for each region

model4_pred_results = pd.DataFrame(columns=['model', 'tuning', 'geo_preds', 'region', 'threshold', 'auc', 'fp', 'fn', 'tp', 
                                     'tn', 'acc', 'num_training_pts', 'percent_irr_training'])
thresholds = np.arange(0.0, 1.1, 0.1)

for regionname in ['SUL', 'CENTRO-OESTE', 'SUDESTE', 'NORDESTE', 'NORTE']:
    
    print(regionname)
    # fit the model for the region ---------------------------------------------

    # set predictors
    numerical_cols_allyears = list(mod_ts_cols_allyears) + phenospectral_cols + missingness_cols
    numerical_cols_nongeo = list(set(numerical_cols_allyears) - set(geographic_cols))
    categorical_cols_nongeo = list(set(categorical_cols) - set(geographic_cols))

    # preprocessing pipelines for both numeric and categorical data
    numerical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean'))])

    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))])

    preprocessor_nongeo = ColumnTransformer(
        transformers=[
            ('num', numerical_transformer, numerical_cols_nongeo),
            ('cat', categorical_transformer, categorical_cols_nongeo)])

    # Append classifier to preprocessing pipeline
    tuned_rf = RandomForestClassifier(n_estimators = 1800, min_samples_split = 2, 
                                       min_samples_leaf = 1, max_features = 'auto', max_depth = 50, 
                                       bootstrap = False)

    pipeline_region = Pipeline(steps=[('preprocessor', preprocessor_nongeo),
                          ('rf', tuned_rf)])


    X_train_region = X_train[X_train.region == regionname]
    y_train_region = y_train[X_train.region == regionname]
    #X_test_region = X_test[X_test.region == regionname]
    #y_test_region = y_test[y_test.region == regionname]
    
    total_train_points = len(y_train_region)
    percent_irr_training = np.mean(y_train_region)

    # training
    pipeline_region.fit(X_train_region, y_train_region)
    
    y_pred_prob = pipeline_region.predict_proba(X_test)[:,1]

    for threshold in thresholds:
        y_pred = np.multiply(np.array(y_pred_prob > threshold), 1)
        conf_mat = confusion_matrix(y_test, y_pred)

        FP = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        FN = conf_mat[1,0]/(conf_mat[1,0] + conf_mat[1,1])
        TP = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        TN = conf_mat[0,0]/(conf_mat[0,0] + conf_mat[0,1])

        acc = (TP + TN)/(FP + FN + TP + TN)

        model4_pred_results = model4_pred_results.append({'model': 'rf', 'tuning': True, 'geo_preds': False, 'region': regionname,
                                           'threshold': threshold, 'auc': auc, 'fp': FP, 'fn': FN, 'tp': TP, 'tn': TN, 'acc': acc,
                                           'num_training_pts': total_train_points, 
                                           'percent_irr_training': percent_irr_training}, ignore_index=True)
print(model4_pred_results)
# Out:
# SUL
# CENTRO-OESTE
# SUDESTE
# NORDESTE
# NORTE
#    model tuning geo_preds        region  threshold       auc        fp  \
# 0     rf   True     False           SUL        0.0  0.908702  0.998894
# 1     rf   True     False           SUL        0.1  0.908702  0.668695
# 2     rf   True     False           SUL        0.2  0.908702  0.426991
# 3     rf   True     False           SUL        0.3  0.908702  0.247788
# 4     rf   True     False           SUL        0.4  0.908702  0.107301
# 5     rf   True     False           SUL        0.5  0.908702  0.034845
# 6     rf   True     False           SUL        0.6  0.908702  0.006637
# 7     rf   True     False           SUL        0.7  0.908702  0.001106
# 8     rf   True     False           SUL        0.8  0.908702  0.000000
# 9     rf   True     False           SUL        0.9  0.908702  0.000000
# 10    rf   True     False           SUL        1.0  0.908702  0.000000
# 11    rf   True     False  CENTRO-OESTE        0.0  0.908702  1.000000
# 12    rf   True     False  CENTRO-OESTE        0.1  0.908702  0.972345
# 13    rf   True     False  CENTRO-OESTE        0.2  0.908702  0.854535
# 14    rf   True     False  CENTRO-OESTE        0.3  0.908702  0.700221
# 15    rf   True     False  CENTRO-OESTE        0.4  0.908702  0.543142
# 16    rf   True     False  CENTRO-OESTE        0.5  0.908702  0.386062
# 17    rf   True     False  CENTRO-OESTE        0.6  0.908702  0.271018
# 18    rf   True     False  CENTRO-OESTE        0.7  0.908702  0.160951
# 19    rf   True     False  CENTRO-OESTE        0.8  0.908702  0.065819
# 20    rf   True     False  CENTRO-OESTE        0.9  0.908702  0.010509
# 21    rf   True     False  CENTRO-OESTE        1.0  0.908702  0.000000
# 22    rf   True     False       SUDESTE        0.0  0.908702  1.000000
# 23    rf   True     False       SUDESTE        0.1  0.908702  1.000000
# 24    rf   True     False       SUDESTE        0.2  0.908702  1.000000
# 25    rf   True     False       SUDESTE        0.3  0.908702  1.000000
# 26    rf   True     False       SUDESTE        0.4  0.908702  0.997235
# 27    rf   True     False       SUDESTE        0.5  0.908702  0.970133
# 28    rf   True     False       SUDESTE        0.6  0.908702  0.898783
# 29    rf   True     False       SUDESTE        0.7  0.908702  0.699115
# 30    rf   True     False       SUDESTE        0.8  0.908702  0.483407
# 31    rf   True     False       SUDESTE        0.9  0.908702  0.220686
# 32    rf   True     False       SUDESTE        1.0  0.908702  0.000000
# 33    rf   True     False      NORDESTE        0.0  0.908702  1.000000
# 34    rf   True     False      NORDESTE        0.1  0.908702  0.966814
# 35    rf   True     False      NORDESTE        0.2  0.908702  0.926438
# 36    rf   True     False      NORDESTE        0.3  0.908702  0.887168
# 37    rf   True     False      NORDESTE        0.4  0.908702  0.849558
# 38    rf   True     False      NORDESTE        0.5  0.908702  0.788717
# 39    rf   True     False      NORDESTE        0.6  0.908702  0.704093
# 40    rf   True     False      NORDESTE        0.7  0.908702  0.575221
# 41    rf   True     False      NORDESTE        0.8  0.908702  0.379425
# 42    rf   True     False      NORDESTE        0.9  0.908702  0.146018
# 43    rf   True     False      NORDESTE        1.0  0.908702  0.000000
# 44    rf   True     False         NORTE        0.0  0.908702  1.000000
# 45    rf   True     False         NORTE        0.1  0.908702  0.704093
# 46    rf   True     False         NORTE        0.2  0.908702  0.449668
# 47    rf   True     False         NORTE        0.3  0.908702  0.294801
# 48    rf   True     False         NORTE        0.4  0.908702  0.173673
# 49    rf   True     False         NORTE        0.5  0.908702  0.094580
# 50    rf   True     False         NORTE        0.6  0.908702  0.025996
# 51    rf   True     False         NORTE        0.7  0.908702  0.001659
# 52    rf   True     False         NORTE        0.8  0.908702  0.000000
# 53    rf   True     False         NORTE        0.9  0.908702  0.000000
# 54    rf   True     False         NORTE        1.0  0.908702  0.000000
#
#           fn        tp        tn       acc num_training_pts  \
# 0   0.000000  1.000000  0.001106  0.500553             2058
# 1   0.082851  0.917149  0.331305  0.624227             2058
# 2   0.246234  0.753766  0.573009  0.663387             2058
# 3   0.435689  0.564311  0.752212  0.658261             2058
# 4   0.614716  0.385284  0.892699  0.638992             2058
# 5   0.807648  0.192352  0.965155  0.578754             2058
# 6   0.923523  0.076477  0.993363  0.534920             2058
# 7   0.974508  0.025492  0.998894  0.512193             2058
# 8   0.985516  0.014484  1.000000  0.507242             2058
# 9   0.990730  0.009270  1.000000  0.504635             2058
# 10  1.000000  0.000000  1.000000  0.500000             2058
# 11  0.000000  1.000000  0.000000  0.500000             2756
# 12  0.001159  0.998841  0.027655  0.513248             2756
# 13  0.012746  0.987254  0.145465  0.566359             2756
# 14  0.057937  0.942063  0.299779  0.620921             2756
# 15  0.121669  0.878331  0.456858  0.667595             2756
# 16  0.232908  0.767092  0.613938  0.690515             2756
# 17  0.362109  0.637891  0.728982  0.683437             2756
# 18  0.519119  0.480881  0.839049  0.659965             2756
# 19  0.707995  0.292005  0.934181  0.613093             2756
# 20  0.881228  0.118772  0.989491  0.554131             2756
# 21  1.000000  0.000000  1.000000  0.500000             2756
# 22  0.000000  1.000000  0.000000  0.500000             2219
# 23  0.000000  1.000000  0.000000  0.500000             2219
# 24  0.000000  1.000000  0.000000  0.500000             2219
# 25  0.000000  1.000000  0.000000  0.500000             2219
# 26  0.000000  1.000000  0.002765  0.501383             2219
# 27  0.002317  0.997683  0.029867  0.513775             2219
# 28  0.017381  0.982619  0.101217  0.541918             2219
# 29  0.086906  0.913094  0.300885  0.606989             2219
# 30  0.232908  0.767092  0.516593  0.641842             2219
# 31  0.548088  0.451912  0.779314  0.615613             2219
# 32  1.000000  0.000000  1.000000  0.500000             2219
# 33  0.000000  1.000000  0.000000  0.500000             1097
# 34  0.002317  0.997683  0.033186  0.515434             1097
# 35  0.004056  0.995944  0.073562  0.534753             1097
# 36  0.007532  0.992468  0.112832  0.552650             1097
# 37  0.016802  0.983198  0.150442  0.566820             1097
# 38  0.029548  0.970452  0.211283  0.590868             1097
# 39  0.074739  0.925261  0.295907  0.610584             1097
# 40  0.145423  0.854577  0.424779  0.639678             1097
# 41  0.375435  0.624565  0.620575  0.622570             1097
# 42  0.739861  0.260139  0.853982  0.557061             1097
# 43  1.000000  0.000000  1.000000  0.500000             1097
# 44  0.000000  1.000000  0.000000  0.500000              113
# 45  0.130359  0.869641  0.295907  0.582774              113
# 46  0.328505  0.671495  0.550332  0.610913              113
# 47  0.528969  0.471031  0.705199  0.588115              113
# 48  0.710313  0.289687  0.826327  0.558007              113
# 49  0.858053  0.141947  0.905420  0.523684              113
# 50  0.964658  0.035342  0.974004  0.504673              113
# 51  0.997103  0.002897  0.998341  0.500619              113
# 52  1.000000  0.000000  1.000000  0.500000              113
# 53  1.000000  0.000000  1.000000  0.500000              113
# 54  1.000000  0.000000  1.000000  0.500000              113
#
#     percent_irr_training
# 0               0.202138
# 1               0.202138
# 2               0.202138
# 3               0.202138
# 4               0.202138
# 5               0.202138
# 6               0.202138
# 7               0.202138
# 8               0.202138
# 9               0.202138
# 10              0.202138
# 11              0.470610
# 12              0.470610
# 13              0.470610
# 14              0.470610
# 15              0.470610
# 16              0.470610
# 17              0.470610
# 18              0.470610
# 19              0.470610
# 20              0.470610
# 21              0.470610
# 22              0.863452
# 23              0.863452
# 24              0.863452
# 25              0.863452
# 26              0.863452
# 27              0.863452
# 28              0.863452
# 29              0.863452
# 30              0.863452
# 31              0.863452
# 32              0.863452
# 33              0.534184
# 34              0.534184
# 35              0.534184
# 36              0.534184
# 37              0.534184
# 38              0.534184
# 39              0.534184
# 40              0.534184
# 41              0.534184
# 42              0.534184
# 43              0.534184
# 44              0.132743
# 45              0.132743
# 46              0.132743
# 47              0.132743
# 48              0.132743
# 49              0.132743
# 50              0.132743
# 51              0.132743
# 52              0.132743
# 53              0.132743
# 54              0.132743

# %%
model4_pred_results[model4_pred_results.region == 'SUDESTE']
# Out:
#    model tuning geo_preds   region  threshold       auc        fp        fn  \
# 22    rf   True     False  SUDESTE        0.0  0.908702  1.000000  0.000000
# 23    rf   True     False  SUDESTE        0.1  0.908702  1.000000  0.000000
# 24    rf   True     False  SUDESTE        0.2  0.908702  1.000000  0.000000
# 25    rf   True     False  SUDESTE        0.3  0.908702  1.000000  0.000000
# 26    rf   True     False  SUDESTE        0.4  0.908702  0.997235  0.000000
# 27    rf   True     False  SUDESTE        0.5  0.908702  0.970133  0.002317
# 28    rf   True     False  SUDESTE        0.6  0.908702  0.898783  0.017381
# 29    rf   True     False  SUDESTE        0.7  0.908702  0.699115  0.086906
# 30    rf   True     False  SUDESTE        0.8  0.908702  0.483407  0.232908
# 31    rf   True     False  SUDESTE        0.9  0.908702  0.220686  0.548088
# 32    rf   True     False  SUDESTE        1.0  0.908702  0.000000  1.000000
#
#           tp        tn       acc num_training_pts  percent_irr_training  \
# 22  1.000000  0.000000  0.500000             2219              0.863452
# 23  1.000000  0.000000  0.500000             2219              0.863452
# 24  1.000000  0.000000  0.500000             2219              0.863452
# 25  1.000000  0.000000  0.500000             2219              0.863452
# 26  1.000000  0.002765  0.501383             2219              0.863452
# 27  0.997683  0.029867  0.513775             2219              0.863452
# 28  0.982619  0.101217  0.541918             2219              0.863452
# 29  0.913094  0.300885  0.606989             2219              0.863452
# 30  0.767092  0.516593  0.641842             2219              0.863452
# 31  0.451912  0.779314  0.615613             2219              0.863452
# 32  0.000000  1.000000  0.500000             2219              0.863452
#
#           threshold_str
# 22                  0.0
# 23                  0.1
# 24                  0.2
# 25  0.30000000000000004
# 26                  0.4
# 27                  0.5
# 28   0.6000000000000001
# 29   0.7000000000000001
# 30                  0.8
# 31                  0.9
# 32                  1.0

# %%
# choose thresholds per region to maximize true positive rate

chosen_thres_dict = {'SUL': 0.2, 'CENTRO-OESTE': 0.4, 'SUDESTE': 0.7, 'NORDESTE': 0.7, 'NORTE': 0.1}

# %%
# fit a separate model to each region (don't use geographic features)
# use a different threshold value for each region

percent_irrigated_perregion = pd.DataFrame({'year' : years_list})

for regionname in ['SUL', 'CENTRO-OESTE', 'SUDESTE', 'NORDESTE', 'NORTE']:
    print(regionname)
    # fit the model for the region ---------------------------------------------

    # set predictors
    numerical_cols_allyears = list(mod_ts_cols_allyears) + phenospectral_cols + missingness_cols
    numerical_cols_nongeo = list(set(numerical_cols_allyears) - set(geographic_cols))
    categorical_cols_nongeo = list(set(categorical_cols) - set(geographic_cols))

    # preprocessing pipelines for both numeric and categorical data
    numerical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean'))])

    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))])

    preprocessor_nongeo = ColumnTransformer(
        transformers=[
            ('num', numerical_transformer, numerical_cols_nongeo),
            ('cat', categorical_transformer, categorical_cols_nongeo)])

    # Append classifier to preprocessing pipeline
    tuned_rf = RandomForestClassifier(n_estimators = 1800, min_samples_split = 2, 
                                       min_samples_leaf = 1, max_features = 'auto', max_depth = 50, 
                                       bootstrap = False)

    pipeline_region = Pipeline(steps=[('preprocessor', preprocessor_nongeo),
                          ('rf', tuned_rf)])


    X_train_region = X_train[X_train.region == regionname]
    y_train_region = y_train[X_train.region == regionname]
    
    # training
    pipeline_region.fit(X_train_region, y_train_region)
    
    
    yearly_percent_irrig = []
    
    for year in years_list:
        data_year = pd.read_csv('predictionpts_cleaned_' + str(year) + '.csv', index_col = 0)
        chosen_predictors = numerical_cols_nongeo + categorical_cols_nongeo
        X_year = data_year[chosen_predictors]
        X_year_region = X_year[data_year.region == regionname]
        #prediction = pipeline_all.predict(X_year_region)
        y_pred_prob = pipeline_region.predict_proba(X_year_region)[:,1]
        chosen_threshold = chosen_thres_dict[regionname]
        prediction = np.multiply(np.array(y_pred_prob > chosen_threshold), 1)

        percent_irrigated = prediction.mean()
        
        # save the year's percent irrigated
        yearly_percent_irrig.append(percent_irrigated)
    
    # save the region's predictions
    percent_irrigated_perregion[regionname] = yearly_percent_irrig
# Out:
# SUL
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# CENTRO-OESTE
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# SUDESTE
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# NORDESTE
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# NORTE
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (115,116,117,118,119,120,121,122,123,124,125,126,127,128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127,128,129,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# plot predictions

tidy_predictions_perregion = percent_irrigated_perregion.melt(id_vars = ['year'], value_name = 'percent_irrigated', 
                                        var_name = 'region')

sns.lineplot(x = 'year', y = 'percent_irrigated', data = tidy_predictions_perregion, hue = 'region')
plt.title('Percent irrigation, predicted; without geographic features, different model per region')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# We use different thresholds for each region because the training points are imbalanced. The southeast has a very high proportion of irrigated points, so the threshold was set higher (at 0.7) to control the number of false positives; the north has a low proportion of irrigated points, so the threshold was set lower (at 0.1) to increase the true positives. These two thresholds produce the same false positive rate of 0.7 for the two regions. We choose to increase the true positive rate at the expense of increasing false positive rate for a conservative estimate of irrigation water use in different regions of Brazil.
#
# While the two models (one in which all of Brazil is fit; another version in which each region is fit to its own model and threshold) produce different magnitudes for the percent irrigated within each region, they agree on the time trends: the northeast is still increasing irrigation, while the southeast is experiencing a decline in irrigation. The north and the south have relatively flat trends overall, but high interannual variability in percent irrigated.

# %% [markdown]
# Conclusion: don't include geographical features in the final model. Avoiding geographical features allows us to predict pattern of irrigation spread in space and doesn't force the model to place weight on the spatial pattern observed in the training year. Although separating models by region would in theory control for seasonality differences across space, it can't control for the interannual variability, which might be as large as the spatial variability. Also, the regions as defined here might not be the best way to divide the country by seasonality type - so we choose to fit the entire country with a single model. If we had much more training data across multiple years, we could have divided the data into categories of seasonality and fit a separate model to each seasonality type.

# %%
model4_pred_results = model4_pred_results.round({'threshold': 1})

accuracy_metrics = model4_pred_results[((model4_pred_results.region == 'SUL') & 
                                        (model4_pred_results.threshold == chosen_thres_dict['SUL'])) |
                                      ((model4_pred_results.region == 'CENTRO-OESTE') & 
                                        (model4_pred_results.threshold == chosen_thres_dict['CENTRO-OESTE'])) |
                                      ((model4_pred_results.region == 'SUDESTE') & 
                                        (model4_pred_results.threshold == chosen_thres_dict['SUDESTE'])) |
                                      ((model4_pred_results.region == 'NORDESTE') & 
                                        (model4_pred_results.threshold == chosen_thres_dict['NORDESTE'])) |
                                      ((model4_pred_results.region == 'NORTE') & 
                                        (model4_pred_results.threshold == chosen_thres_dict['NORTE']))]
print(accuracy_metrics.loc[:, ['region', 'threshold', 'fp', 'fn', 'tp', 'tn', 'percent_irr_training']])
# Out:
#           region  threshold        fp        fn        tp        tn  \
# 2            SUL        0.2  0.426991  0.246234  0.753766  0.573009
# 15  CENTRO-OESTE        0.4  0.543142  0.121669  0.878331  0.456858
# 29       SUDESTE        0.7  0.699115  0.086906  0.913094  0.300885
# 40      NORDESTE        0.7  0.575221  0.145423  0.854577  0.424779
# 45         NORTE        0.1  0.704093  0.130359  0.869641  0.295907
#
#     percent_irr_training
# 2               0.202138
# 15              0.470610
# 29              0.863452
# 40              0.534184
# 45              0.132743
